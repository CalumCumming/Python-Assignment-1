# %% [markdown]
# # Code

# %%
from tabulate import tabulate #imports tabulate library to allow for creation of tables

def read_tree_names(tree_file_path): #reads trees.txt file and adds the tree names to the empty list trees
    trees = []
    with open(tree_file_path, 'r') as file:
        for line in file:
            trees.append(line.strip())
    return trees

def tokenize_name(tree): #simplifies the large tree file and breaks down each name
    words = [word.strip("'") for word in tree.split() if word.isalpha()] #word.isalpha() ensures that hyphens and apostrophes arent added to the potential abbreviations
    words_uppercase = [word.upper() for word in words]
    return words_uppercase

def read_values_file(values_file_path): #reads the values.txt file from the created variable values_file_path
    values_dict = {} #stores them in this created empty list
    with open(values_file_path, 'r') as file:
        for line in file:
            letter, value = line.split() #splits the letter and its corresponding value into a list to match the 2 variables together
            values_dict[letter] = int(value) #changes the value to an integer
    return values_dict

def calculate_letter_score(letter, values_dict, tree):
    words = tokenize_name(tree)

    rarity_value = 0 #assigning the initial rarity_value

    for word in words:
        position = word.find(letter) + 1

        if position == 1:
            rarity_value = values_dict.get(letter, 0)
        elif position == len(word):
            if letter == 'E': #assigning the required rules, so if the last letter of a word is E it has a value of 20
                rarity_value = 20
            else: #otherwise the last letter has a value of 5
                rarity_value = 5

        if 1 < position < len(word):
            rarity_value = values_dict.get(letter, 0)

    return rarity_value

def generate_abbreviations_with_values(trees, values_dict):
    tree_and_abbreviations_with_values = []

    trees.sort() #sorts the trees in alphabetical order

    for tree in trees:
        words = tokenize_name(tree)

        if words:
            first_letter = tree[0] #ensures the first letter is assigned a score of 0

            for word in words:
                if len(word) >= 3:
                    for i in range(len(word) - 2):
                        for j in range(i + 1, len(word) - 1): #for loops generating indices and generates starting and ending positions for potential substrings
                            if word[i] != first_letter: #!= is the not equal operator in python, means the first letter in each abbreviation isn't duplicated
                                abbreviation = (first_letter + word[i] + word[j]) #word[i] can be thought of as the second letter, word[j] as the third letter

                                position = word.find(word[i]) + 1
                                position_value_1 = 1 if position == 2 else (2 if position == 3 else 3)

                                position = word.find(word[j]) + 1
                                position_value_2 = 1 if position == 2 else (2 if position == 3 else 3)

                                position_value = position_value_1 + position_value_2

                                second_let_score = calculate_letter_score(word[i], values_dict, tree) #calculates the score for the second letter using the position, letter value and tree name
                                third_let_score = calculate_letter_score(word[j], values_dict, tree) #calculates the score for the third letter using the position, letter value and tree name

                                abbreviation_score = second_let_score + third_let_score + position_value

                                tree_and_abbreviations_with_values.append((abbreviation, abbreviation_score, tree)) #joins these 3 variables together

    return tree_and_abbreviations_with_values

trees_file_path = ('/Users/CCumm/OneDrive/Documents/AC50002/Python Assignment/trees.txt') #file path for trees.txt file
values_file_path = ('/Users/CCumm/OneDrive/Documents/AC50002/Python Assignment/values.txt') #file path for values.txt file

trees = read_tree_names(trees_file_path)
values_dict = read_values_file(values_file_path)

all_abbreviations = []

for tree in trees:
    abbreviations_for_tree = generate_abbreviations_with_values([tree], values_dict)
    all_abbreviations.extend(abbreviations_for_tree)

table_data = [] #creates sorted data ready to be displayed as a table by extracting each piece of required info from each entry
for entry in sorted(all_abbreviations, key=lambda x: x[1]): #lambda is crucial for sorting elements
    abbr, score, current_name = entry
    table_data.append([current_name, abbr.upper(), score])

table_data_sorted = sorted(table_data, key=lambda x: x[0])

table_headings = ["Name", "Abbreviation", "Score"] #defines the table headings
print(tabulate(table_data_sorted, headers=table_headings, tablefmt="rounded_grid")) #prints the table with the headings, formatted with the rounded_grid option


def main(): #defining the main function
    try:
        input_filename = input("Enter the input file name: ") #insert file path here for trees.txt
        output_filename = "Cumming_trees_abbrev.txt" #generates an output file with this name

        trees = read_tree_names(input_filename)
        values_dict = read_values_file('/Users/CCumm/OneDrive/Documents/AC50002/Python Assignment/values.txt')

        with open(output_filename, 'w') as output_file:
            for entry in all_abbreviations:
                abbreviation, score, current_name = entry
                output_file.write(f"{current_name} {abbreviation} {score}\n")

        print(f"Results written to {output_filename}") #displays if the output is successfully created

    except FileNotFoundError: #displays if the input file was incorrect
        print(f"Error: File '{input_filename}' not found.")
    except Exception as e:
        print(f"An error occurred: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# ╭──────────────────────┬────────────────┬─────────╮
# │ Name                 │ Abbreviation   │   Score │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder                │ ALD            │      27 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder                │ ADE            │      49 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder                │ ALE            │      54 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ ACK            │      19 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ AKH            │      19 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ ABK            │      20 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ ACH            │      20 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ ABC            │      21 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ ABH            │      21 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ ALD            │      27 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ AKT            │      27 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ AKR            │      27 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ ACT            │      28 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ ACR            │      28 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ ATH            │      28 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ AHR            │      28 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ ABT            │      29 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ ABR            │      29 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ AUK            │      30 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ AUC            │      31 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ AUH            │      31 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ ABU            │      32 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ AKO            │      32 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ ACO            │      33 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ AHO            │      33 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ ABO            │      34 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ ATR            │      36 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ AUT            │      39 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ AUR            │      39 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ ATO            │      41 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ AOR            │      41 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ AUO            │      44 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ ADE            │      49 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Alder Buckthorn      │ ALE            │      54 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Almond-leaved Willow │ AWL            │      27 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Almond-leaved Willow │ AWL            │      27 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Almond-leaved Willow │ AWO            │      33 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Almond-leaved Willow │ ALL            │      34 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Almond-leaved Willow │ AWI            │      36 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Almond-leaved Willow │ ALO            │      40 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Almond-leaved Willow │ ALO            │      40 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Almond-leaved Willow │ AIL            │      43 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Almond-leaved Willow │ AIL            │      43 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Almond-leaved Willow │ AIO            │      49 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Aspen                │ ASP            │      26 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Aspen                │ APE            │      48 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Aspen                │ ASE            │      54 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Bay Willow           │ BWL            │      27 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Bay Willow           │ BWL            │      27 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Bay Willow           │ BWO            │      33 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Bay Willow           │ BLL            │      34 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Bay Willow           │ BWI            │      36 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Bay Willow           │ BLO            │      40 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Bay Willow           │ BLO            │      40 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Bay Willow           │ BIL            │      43 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Bay Willow           │ BIL            │      43 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Bay Willow           │ BIO            │      49 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Bird Cherry          │ BCH            │      19 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Bird Cherry          │ BHR            │      26 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Bird Cherry          │ BHR            │      26 │
# ├──────────────────────┼────────────────┼─────────┤
# │
│      27 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Midland Hawthorn     │ MWR            │      27 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Midland Hawthorn     │ MHT            │      28 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Midland Hawthorn     │ MHR            │      28 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Midland Hawthorn     │ MTH            │      28 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Midland Hawthorn     │ MHR            │      28 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Midland Hawthorn     │ MDL            │      29 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Midland Hawthorn     │ MWO            │      32 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Midland Hawthorn     │ MHO            │      33 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Midland Hawthorn     │ MHO            │      33 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Midland Hawthorn     │ MIN            │      34 │
# ├──────────────────────┼────────────────┼─────────┤
# ...
# ├──────────────────────┼────────────────┼─────────┤
# │ Sallow               │ SLL            │      34 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Sallow               │ SLO            │      40 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Sallow               │ SLO            │      40 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Sallow               │ SAL            │      43 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Sallow               │ SAL            │      43 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Sallow               │ SAO            │      49 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Scots Pine           │ SCT            │      27 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Scots Pine           │ SPN            │      28 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Scots Pine           │ SCO            │      31 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Scots Pine           │ SPI            │      37 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Scots Pine           │ SOT            │      40 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Scots Pine           │ SIN            │      43 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Service Tree         │ SVC            │      21 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Service Tree         │ SRV            │      27 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Service Tree         │ SRC            │      28 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Service Tree         │ STR            │      34 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Service Tree         │ SVI            │      38 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Service Tree         │ SIC            │      39 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Service Tree         │ SRI            │      45 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Service Tree         │ SEV            │      46 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Service Tree         │ SEC            │      47 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Service Tree         │ SER            │      53 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Service Tree         │ SRE            │      53 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Service Tree         │ STE            │      55 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Service Tree         │ SEI            │      64 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Sessile Oak          │ SIL            │      46 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Sessile Oak          │ SOA            │      49 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Sessile Oak          │ SES            │      54 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Sessile Oak          │ SES            │      54 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Sessile Oak          │ SEL            │      54 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Sessile Oak          │ SEI            │      64 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Silver Birch         │ SBC            │      22 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Silver Birch         │ SLV            │      27 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Silver Birch         │ SBR            │      28 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Silver Birch         │ SRC            │      28 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Silver Birch         │ SIV            │      36 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Silver Birch         │ SBI            │      37 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Silver Birch         │ SIC            │      37 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Silver Birch         │ SIL            │      43 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Silver Birch         │ SIR            │      43 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Silver Birch         │ SVE            │      48 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Silver Birch         │ SLE            │      55 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Silver Birch         │ SIE            │      64 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Small-leaved Lime    │ SLM            │      28 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Small-leaved Lime    │ SIM            │      36 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Small-leaved Lime    │ SLI            │      44 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Smooth-leaved Elm    │ SEL            │      54 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Spindle              │ SPD            │      21 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Spindle              │ SPN            │      27 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Spindle              │ SPL            │      27 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Spindle              │ SND            │      30 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Spindle              │ SDL            │      30 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Spindle              │ SPI            │      36 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Spindle              │ SNL            │      36 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Spindle              │ SID            │      39 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Spindle              │ SIN            │      45 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Spindle              │ SIL            │      45 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ SWB            │      21 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ STW            │      26 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ STB            │      27 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ SRW            │      27 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ SWR            │      27 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ SWR            │      27 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ SRB            │      28 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ SBR            │      28 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ SBR            │      28 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ STR            │      33 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ STR            │      33 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ STR            │      33 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ SRR            │      34 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ SRR            │      34 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ SRR            │      34 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ STR            │      34 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ SAW            │      38 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ SAB            │      39 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ STA            │      44 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ SRA            │      45 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ SAR            │      45 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ SAR            │      45 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ SWE            │      48 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ SBE            │      49 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ SRE            │      53 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ STE            │      54 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ SRE            │      55 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ SER            │      55 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ SER            │      55 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ STE            │      55 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Strawberry Tree      │ SAE            │      66 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wayfaring tree       │ WYF            │      19 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wayfaring tree       │ WYR            │      27 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wayfaring tree       │ WYN            │      27 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wayfaring tree       │ WFR            │      28 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wayfaring tree       │ WFN            │      28 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wayfaring tree       │ WTR            │      34 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wayfaring tree       │ WAY            │      35 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wayfaring tree       │ WYA            │      35 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wayfaring tree       │ WAF            │      36 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wayfaring tree       │ WFA            │      36 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wayfaring tree       │ WRN            │      36 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wayfaring tree       │ WYI            │      37 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wayfaring tree       │ WFI            │      38 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wayfaring tree       │ WAR            │      44 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wayfaring tree       │ WAN            │      44 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wayfaring tree       │ WAR            │      44 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wayfaring tree       │ WAN            │      44 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wayfaring tree       │ WRI            │      46 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wayfaring tree       │ WIN            │      46 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wayfaring tree       │ WAA            │      52 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wayfaring tree       │ WRE            │      53 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wayfaring tree       │ WAI            │      54 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wayfaring tree       │ WAI            │      54 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wayfaring tree       │ WTE            │      55 │
# ├──────────────────────┼────────────────┼─────────┤
# │ White Willow         │ WHT            │      26 │
# ├──────────────────────┼────────────────┼─────────┤
# │ White Willow         │ WLL            │      34 │
# ├──────────────────────┼────────────────┼─────────┤
# │ White Willow         │ WHI            │      35 │
# ├──────────────────────┼────────────────┼─────────┤
# │ White Willow         │ WLO            │      40 │
# ├──────────────────────┼────────────────┼─────────┤
# │ White Willow         │ WLO            │      40 │
# ├──────────────────────┼────────────────┼─────────┤
# │ White Willow         │ WIL            │      43 │
# ├──────────────────────┼────────────────┼─────────┤
# │ White Willow         │ WIL            │      43 │
# ├──────────────────────┼────────────────┼─────────┤
# │ White Willow         │ WIT            │      45 │
# ├──────────────────────┼────────────────┼─────────┤
# │ White Willow         │ WIO            │      49 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Cherry          │ WCH            │      19 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Cherry          │ WHR            │      26 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Cherry          │ WHR            │      26 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Cherry          │ WCR            │      29 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Cherry          │ WCR            │      29 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Cherry          │ WRR            │      36 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Cherry          │ WIL            │      43 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Cherry          │ WHE            │      45 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Cherry          │ WCE            │      48 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Cherry          │ WER            │      55 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Cherry          │ WER            │      55 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Service Tree    │ WVC            │      21 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Service Tree    │ WRV            │      27 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Service Tree    │ WSV            │      28 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Service Tree    │ WRC            │      28 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Service Tree    │ WSC            │      29 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Service Tree    │ WTR            │      34 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Service Tree    │ WSR            │      35 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Service Tree    │ WVI            │      38 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Service Tree    │ WIC            │      39 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Service Tree    │ WIL            │      43 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Service Tree    │ WRI            │      45 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Service Tree    │ WSI            │      46 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Service Tree    │ WEV            │      46 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Service Tree    │ WEC            │      47 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Service Tree    │ WER            │      53 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Service Tree    │ WRE            │      53 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Service Tree    │ WSE            │      54 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Service Tree    │ WTE            │      55 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wild Service Tree    │ WEI            │      64 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wych Elm             │ WYC            │      18 │
# ├──────────────────────┼────────────────┼─────────┤
# │ Wych Elm             │ WEL            │      54 │
# ╰──────────────────────┴────────────────┴─────────╯
